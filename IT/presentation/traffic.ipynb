# %%
import pandas as pd

# %%
data = pd.read_csv('ForExport.csv')
data.tail()
# Out:
#        Country      City            UpdateTimeUTC  JamsDelay  \
# 189105     ZAF  pretoria  2024-10-01 12:31:30.000      195.1
# 189106     ZAF  pretoria  2024-10-01 11:31:30.000       78.3
# 189107     ZAF  pretoria  2024-10-01 10:01:30.000       85.0
# 189108     ZAF  pretoria  2024-10-01 09:01:30.000       68.1
# 189109     ZAF  pretoria  2024-10-01 08:46:30.000       67.7
#
#         TrafficIndexLive  JamsLengthInKms  JamsCount  TrafficIndexWeekAgo  \
# 189105              27.0             27.2       66.0                 14.0
# 189106              22.0              9.2       27.0                 15.0
# 189107              21.0              9.7       29.0                 16.0
# 189108              20.0              6.7       23.0                 15.0
# 189109              20.0              6.6       22.0                 13.0
#
#            UpdateTimeUTCWeekAgo  TravelTimeLivePer10KmsMins  \
# 189105  2024-09-24 12:01:30.001                   14.930880
# ...
